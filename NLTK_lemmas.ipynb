# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk import stem
stemmer = stem.PorterStemmer()
from nltk import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
stops = set(stopwords.words('english'))
import string
punct = list(string.punctuation)
from collections import Counter
import requests
import pandas as pd
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
#!pip install PRAW
import numpy as np
import praw
import datetime
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jamescarney/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # The basics of lemmatising and stemming

# %%
sent = "The quick brown fox jumped over the lazy dogs. The community of fowl sang in the dawn. The blind mice retreated before the feral felines. The geese flew north to escape the wolves"

# %%
words = word_tokenize(sent)
stems = [stemmer.stem(i) for i in words]
lemmas = [lemmatizer.lemmatize(i) for i in words]

# %%
with open('wuthering_heights.txt', 'r') as f:
    text = f.read()

# %%
text = text.encode('ascii', 'ignore')
text = text.decode()

# %%
text = ' '.join(text.splitlines())
text = text.lower()

# %%
words = word_tokenize(text)

# %%
words[:6]
# Out:
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'wuthering']

# %%
lemmas = [lemmatizer.lemmatize(i) for i in words]

# %%
lemmas = [i for i in lemmas if i not in stops and i not in punct]

# %%
counts = pd.Series(Counter(lemmas))

# %%
counts
# Out:
# project        91
# gutenberg      31
# ebook          13
# wuthering      66
# height        106
#              ...
# network         1
# pg              1
# facility        1
# subscribe       1
# newsletter      1
# Length: 9568, dtype: int64

# %%
sns.displot(counts, kind = 'kde')
plt.show()

# %%
sns.lineplot(x = [len(i) for i in counts.index], y = [i for i in counts.values])
# Out:
# <AxesSubplot:>

# %%
counts.sort_values()
# Out:
# 'december'

# %% [markdown]
# # Using APIs to obtain data

# %% [markdown]
# ## [Tracking the UK's journey to carbon zero](https://data.climateemergency.uk/)

# %%
URL = 'https://data.climateemergency.uk/api/searchterms/'

URL2 = "https://data.climateemergency.uk/api/commitments/"

PARAMS = {'min_results':1}

r = requests.get(url = URL, params = PARAMS)

r = r.json()

# %%
r['results'][0]
# Out:
# {'user_query': '"circular economy"',
#  'result_count': 234,
#  'times_seen': 4306,
#  'council_restriction': ''}

# %% [markdown]
# ## [The Project Gutenberg API](https://gutendex.com/books/)

# %%
params_g = {'topic':'love'}

gut = 'https://gutendex.com/books/'

rg = r = requests.get(url = gut, params = params_g)

# %%
rg.json()
# Out:
# {'count': 1141,
#  'next': 'https://gutendex.com/books/?page=2&topic=love',
#  'previous': None,
#  'results': [{'id': 145,
#    'title': 'Middlemarch',
#    'authors': [{'name': 'Eliot, George',
#      'birth_year': 1819,
#      'death_year': 1880}],
#    'translators': [],
#    'subjects': ['Bildungsromans',
#     'City and town life -- Fiction',
#     'Didactic fiction',
#     'Domestic fiction',
#     'England -- Fiction',
#     'Love stories',
#     'Married people -- Fiction',
#     'Young women -- Fiction'],
#    'bookshelves': ['Best Books Ever Listings', 'Historical Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/145.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/145.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/145.html.images',
#     'application/octet-stream': 'https://www.gutenberg.org/files/145/145-0.zip',
#     'text/plain': 'https://www.gutenberg.org/ebooks/145.txt.utf-8',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/145/pg145.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/145/145-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/145.rdf'},
#    'download_count': 148783},
#   {'id': 67979,
#    'title': 'The Blue Castle: a novel',
#    'authors': [{'name': 'Montgomery, L. M. (Lucy Maud)',
#      'birth_year': 1874,
#      'death_year': 1942}],
#    'translators': [],
#    'subjects': ['Canada -- History -- 1914-1945 -- Fiction',
#     'Choice -- Fiction',
#     'Love -- Fiction',
#     'Romance fiction',
#     'Self-actualization (Psychology) -- Fiction',
#     'Single women -- Fiction',
#     'Young adult fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/67979.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/67979.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/67979.html.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/67979/pg67979.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/67979/67979-0.zip',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/67979.rdf',
#     'text/plain': 'https://www.gutenberg.org/ebooks/67979.txt.utf-8',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/67979/67979-0.txt'},
#    'download_count': 137375},
#   {'id': 16389,
#    'title': 'The Enchanted April',
#    'authors': [{'name': 'Von Arnim, Elizabeth',
#      'birth_year': 1866,
#      'death_year': 1941}],
#    'translators': [],
#    'subjects': ['British -- Italy -- Fiction',
#     'Domestic fiction',
#     'Female friendship -- Fiction',
#     'Italy -- Fiction',
#     'Love stories'],
#    'bookshelves': ['Bestsellers, American, 1895-1923'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/16389.kf8.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/16389.html.images',
#     'application/octet-stream': 'https://www.gutenberg.org/files/16389/16389-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/16389/16389-0.txt',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/16389.epub3.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/16389/pg16389.cover.medium.jpg',
#     'text/plain': 'https://www.gutenberg.org/ebooks/16389.txt.utf-8',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/16389.rdf'},
#    'download_count': 134832},
#   {'id': 1342,
#    'title': 'Pride and Prejudice',
#    'authors': [{'name': 'Austen, Jane',
#      'birth_year': 1775,
#      'death_year': 1817}],
#    'translators': [],
#    'subjects': ['Courtship -- Fiction',
#     'Domestic fiction',
#     'England -- Fiction',
#     'Love stories',
#     'Sisters -- Fiction',
#     'Social classes -- Fiction',
#     'Young women -- Fiction'],
#    'bookshelves': ['Best Books Ever Listings', 'Harvard Classics'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/octet-stream': 'https://www.gutenberg.org/files/1342/1342-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/1342/1342-0.txt',
#     'text/plain': 'https://www.gutenberg.org/ebooks/1342.txt.utf-8',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/1342.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/1342.epub3.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/1342/pg1342.cover.medium.jpg',
#     'text/html': 'https://www.gutenberg.org/ebooks/1342.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/1342.rdf'},
#    'download_count': 44819},
#   {'id': 64317,
#    'title': 'The Great Gatsby',
#    'authors': [{'name': 'Fitzgerald, F. Scott (Francis Scott)',
#      'birth_year': 1896,
#      'death_year': 1940}],
#    'translators': [],
#    'subjects': ['First loves -- Fiction',
#     'Long Island (N.Y.) -- Fiction',
#     'Married women -- Fiction',
#     'Psychological fiction',
#     'Rich people -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/64317.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/64317.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/64317.html.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/64317/pg64317.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/64317/64317-0.zip',
#     'text/plain': 'https://www.gutenberg.org/ebooks/64317.txt.utf-8',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/64317/64317-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/64317.rdf'},
#    'download_count': 20487},
#   {'id': 1260,
#    'title': 'Jane Eyre: An Autobiography',
#    'authors': [{'name': 'Brontë, Charlotte',
#      'birth_year': 1816,
#      'death_year': 1855}],
#    'translators': [],
#    'subjects': ['Bildungsromans',
#     'Charity-schools -- Fiction',
#     'Country homes -- Fiction',
#     'England -- Fiction',
#     'Fathers and daughters -- Fiction',
#     'Governesses -- Fiction',
#     'Love stories',
#     'Married people -- Fiction',
#     'Mentally ill women -- Fiction',
#     'Orphans -- Fiction',
#     'Young women -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/1260.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/1260.epub3.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/1260/pg1260.cover.medium.jpg',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/1260/1260-0.txt',
#     'text/html; charset=utf-8': 'https://www.gutenberg.org/files/1260/1260-h/1260-h.htm',
#     'text/html': 'https://www.gutenberg.org/ebooks/1260.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/1260.rdf'},
#    'download_count': 11238},
#   {'id': 768,
#    'title': 'Wuthering Heights',
#    'authors': [{'name': 'Brontë, Emily',
#      'birth_year': 1818,
#      'death_year': 1848}],
#    'translators': [],
#    'subjects': ['Domestic fiction',
#     'Foundlings -- Fiction',
#     'Heathcliff (Fictitious character : Brontë) -- Fiction',
#     'Love stories',
#     'Psychological fiction',
#     'Rejection (Psychology) -- Fiction',
#     'Revenge -- Fiction',
#     'Rural families -- Fiction',
#     'Triangles (Interpersonal relations) -- Fiction',
#     'Yorkshire (England) -- Fiction'],
#    'bookshelves': ['Best Books Ever Listings',
#     'Gothic Fiction',
#     'Movie Books'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/768.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/768.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/768.html.images',
#     'application/octet-stream': 'https://www.gutenberg.org/files/768/768-0.zip',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/768/pg768.cover.medium.jpg',
#     'text/plain': 'https://www.gutenberg.org/ebooks/768.txt.utf-8',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/768/768-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/768.rdf'},
#    'download_count': 7674},
#   {'id': 1399,
#    'title': 'Anna Karenina',
#    'authors': [{'name': 'Tolstoy, Leo, graf',
#      'birth_year': 1828,
#      'death_year': 1910}],
#    'translators': [{'name': 'Garnett, Constance',
#      'birth_year': 1861,
#      'death_year': 1946}],
#    'subjects': ['Adultery -- Fiction',
#     'Didactic fiction',
#     'Love stories',
#     'Married women -- Fiction',
#     'Russia -- Fiction'],
#    'bookshelves': ['Best Books Ever Listings',
#     'Harvard Classics',
#     'Movie Books'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/1399.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/1399.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/1399.html.images',
#     'text/plain': 'https://www.gutenberg.org/ebooks/1399.txt.utf-8',
#     'application/octet-stream': 'https://www.gutenberg.org/files/1399/1399-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/1399/1399-0.txt',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/1399/pg1399.cover.medium.jpg',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/1399.rdf'},
#    'download_count': 7317},
#   {'id': 27827,
#    'title': 'The Kama Sutra of Vatsyayana: Translated From the Sanscrit in Seven Parts With Preface, Introduction and Concluding Remarks',
#    'authors': [{'name': 'Vatsyayana', 'birth_year': None, 'death_year': None}],
#    'translators': [{'name': 'Burton, Richard Francis, Sir',
#      'birth_year': 1821,
#      'death_year': 1890},
#     {'name': 'Bhide, Shivaram Parashuram',
#      'birth_year': None,
#      'death_year': None},
#     {'name': 'Indrajit, Bhagavanlal', 'birth_year': None, 'death_year': None}],
#    'subjects': ['Love', 'Sex'],
#    'bookshelves': ["Banned Books from Anne Haight's list",
#     'Erotic Fiction',
#     'Sociology'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/27827.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/27827.epub3.images',
#     'text/plain; charset=iso-8859-1': 'https://www.gutenberg.org/files/27827/27827-8.txt',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/27827/27827.txt',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/27827/pg27827.cover.medium.jpg',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/27827/27827-h/27827-h.htm',
#     'text/html': 'https://www.gutenberg.org/ebooks/27827.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/27827.rdf',
#     'text/plain': 'https://www.gutenberg.org/ebooks/27827.txt.utf-8'},
#    'download_count': 7204},
#   {'id': 158,
#    'title': 'Emma',
#    'authors': [{'name': 'Austen, Jane',
#      'birth_year': 1775,
#      'death_year': 1817}],
#    'translators': [],
#    'subjects': ['Bildungsromans',
#     'England -- Fiction',
#     'Fathers and daughters -- Fiction',
#     'Female friendship -- Fiction',
#     'Humorous stories',
#     'Love stories',
#     'Mate selection -- Fiction',
#     'Young women -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/158.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/158.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/158.html.images',
#     'application/octet-stream': 'https://www.gutenberg.org/files/158/158-0.zip',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/158/pg158.cover.medium.jpg',
#     'text/plain': 'https://www.gutenberg.org/ebooks/158.txt.utf-8',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/158/158-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/158.rdf'},
#    'download_count': 6500},
#   {'id': 161,
#    'title': 'Sense and Sensibility',
#    'authors': [{'name': 'Austen, Jane',
#      'birth_year': 1775,
#      'death_year': 1817}],
#    'translators': [],
#    'subjects': ['Domestic fiction',
#     'England -- Fiction',
#     'England -- Social life and customs -- 19th century -- Fiction',
#     'Gentry -- England -- Fiction',
#     'Inheritance and succession -- Fiction',
#     'Love stories',
#     'Mate selection -- Fiction',
#     'Regency fiction',
#     'Sisters -- Fiction',
#     'Social classes -- Fiction',
#     'Young women -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/161.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/161.epub3.images',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/161/161-h/161-h.htm',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/161/pg161.cover.medium.jpg',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/161/161-0.txt',
#     'text/html': 'https://www.gutenberg.org/ebooks/161.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/161.rdf'},
#    'download_count': 5473},
#   {'id': 105,
#    'title': 'Persuasion',
#    'authors': [{'name': 'Austen, Jane',
#      'birth_year': 1775,
#      'death_year': 1817}],
#    'translators': [],
#    'subjects': ['Dysfunctional families -- Fiction',
#     'England -- Social life and customs -- 19th century -- Fiction',
#     'First loves -- Fiction',
#     'Love stories',
#     'Motherless families -- Fiction',
#     'Psychological fiction',
#     'Regency fiction',
#     'Rejection (Psychology) -- Fiction',
#     'Ship captains -- Fiction',
#     'Young women -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/105.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/105.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/105.html.images',
#     'application/octet-stream': 'https://www.gutenberg.org/files/105/105-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/105/105-0.txt',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/3/1/1/0/31100/31100-h.zip',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/105/pg105.cover.medium.jpg',
#     'text/plain': 'https://www.gutenberg.org/ebooks/105.txt.utf-8',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/105.rdf'},
#    'download_count': 4814},
#   {'id': 1250,
#    'title': 'Anthem',
#    'authors': [{'name': 'Rand, Ayn', 'birth_year': 1905, 'death_year': 1982}],
#    'translators': [],
#    'subjects': ['Individuality -- Fiction',
#     'Love stories',
#     'Men -- Psychology -- Fiction',
#     'Psychological fiction',
#     'Science fiction',
#     'Time travel -- Fiction'],
#    'bookshelves': ['Science Fiction', 'Science Fiction by Women'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/1250.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/1250.epub3.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/1250/pg1250.cover.medium.jpg',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/1250/1250-0.txt',
#     'text/html; charset=us-ascii': 'https://www.gutenberg.org/files/1250/1250-h/1250-h.htm',
#     'text/html': 'https://www.gutenberg.org/ebooks/1250.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/1250.rdf'},
#    'download_count': 3950},
#   {'id': 121,
#    'title': 'Northanger Abbey',
#    'authors': [{'name': 'Austen, Jane',
#      'birth_year': 1775,
#      'death_year': 1817}],
#    'translators': [],
#    'subjects': ['Books and reading -- Fiction',
#     'England -- Fiction',
#     'England -- Social life and customs -- 19th century -- Fiction',
#     'Gentry -- England -- Fiction',
#     'Gothic fiction',
#     'Horror tales -- Appreciation -- Fiction',
#     'Love stories',
#     'Marriage -- Economic aspects -- Fiction',
#     'Satire',
#     'Young women -- Fiction'],
#    'bookshelves': ['Gothic Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/121.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/121.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/121.html.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/121/pg121.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/121/121-0.zip',
#     'text/plain': 'https://www.gutenberg.org/ebooks/121.txt.utf-8',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/121/121-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/121.rdf'},
#    'download_count': 3092},
#   {'id': 2527,
#    'title': 'The Sorrows of Young Werther',
#    'authors': [{'name': 'Goethe, Johann Wolfgang von',
#      'birth_year': 1749,
#      'death_year': 1832}],
#    'translators': [{'name': 'Boylan, R. Dillon',
#      'birth_year': None,
#      'death_year': None}],
#    'subjects': ['Germany -- Social life and customs -- Fiction',
#     'Unrequited love -- Fiction',
#     'Young men -- Germany -- Fiction'],
#    'bookshelves': ["Banned Books from Anne Haight's list",
#     'Harvard Classics',
#     'Opera'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/2527.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/2527.epub3.images',
#     'text/html; charset=us-ascii': 'https://www.gutenberg.org/files/2527/2527-h/2527-h.htm',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/2527/2527.txt',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/2527/pg2527.cover.medium.jpg',
#     'text/html': 'https://www.gutenberg.org/ebooks/2527.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/2527.rdf',
#     'text/plain': 'https://www.gutenberg.org/ebooks/2527.txt.utf-8'},
#    'download_count': 2700},
#   {'id': 141,
#    'title': 'Mansfield Park',
#    'authors': [{'name': 'Austen, Jane',
#      'birth_year': 1775,
#      'death_year': 1817}],
#    'translators': [],
#    'subjects': ['Adoptees -- Fiction',
#     'Children of the rich -- Fiction',
#     'Country homes -- Fiction',
#     'Cousins -- Fiction',
#     'Domestic fiction',
#     'England -- Fiction',
#     'Love stories',
#     'Uncles -- Fiction',
#     'Young women -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/141.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/141.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/141.html.images',
#     'application/octet-stream': 'https://www.gutenberg.org/files/141/141-0.zip',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/141/pg141.cover.medium.jpg',
#     'text/plain': 'https://www.gutenberg.org/ebooks/141.txt.utf-8',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/141/141-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/141.rdf'},
#    'download_count': 2540},
#   {'id': 2000,
#    'title': 'Don Quijote',
#    'authors': [{'name': 'Cervantes Saavedra, Miguel de',
#      'birth_year': 1547,
#      'death_year': 1616}],
#    'translators': [],
#    'subjects': ['Knights and knighthood -- Spain -- Fiction',
#     'Picaresque literature',
#     'Romances',
#     'Spain -- Social life and customs -- 16th century -- Fiction'],
#    'bookshelves': ['6 Best Loved Spanish Literary Classics',
#     'Best Books Ever Listings',
#     'Harvard Classics'],
#    'languages': ['es'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/2000.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/2000.epub3.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/2000/pg2000.cover.medium.jpg',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/2000/2000-0.txt',
#     'text/html; charset=utf-8': 'https://www.gutenberg.org/files/2000/2000-h/2000-h.htm',
#     'text/html': 'https://www.gutenberg.org/ebooks/2000.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/2000.rdf'},
#    'download_count': 2492},
#   {'id': 541,
#    'title': 'The Age of Innocence',
#    'authors': [{'name': 'Wharton, Edith',
#      'birth_year': 1862,
#      'death_year': 1937}],
#    'translators': [],
#    'subjects': ['Domestic fiction',
#     'Love stories',
#     'Married people -- Fiction',
#     'New York (N.Y.) -- Fiction',
#     'Separated people -- Fiction',
#     'Triangles (Interpersonal relations) -- Fiction',
#     'Upper class -- Fiction'],
#    'bookshelves': ['Bestsellers, American, 1895-1923', 'Movie Books'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/541.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/541.epub3.images',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/541/541.txt',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/541/pg541.cover.medium.jpg',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/541/541-h/541-h.htm',
#     'text/html': 'https://www.gutenberg.org/ebooks/541.html.images',
#     'text/plain': 'https://www.gutenberg.org/ebooks/541.txt.utf-8',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/541.rdf'},
#    'download_count': 1888},
#   {'id': 42671,
#    'title': 'Pride and Prejudice',
#    'authors': [{'name': 'Austen, Jane',
#      'birth_year': 1775,
#      'death_year': 1817}],
#    'translators': [],
#    'subjects': ['Courtship -- Fiction',
#     'Domestic fiction',
#     'England -- Fiction',
#     'Love stories',
#     'Sisters -- Fiction',
#     'Social classes -- Fiction',
#     'Young women -- Fiction'],
#    'bookshelves': ['Best Books Ever Listings'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/42671.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/42671.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/42671.html.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/42671/pg42671.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/42671/42671.txt',
#     'text/plain; charset=iso-8859-1': 'https://www.gutenberg.org/files/42671/42671-8.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/42671.rdf',
#     'text/plain': 'https://www.gutenberg.org/ebooks/42671.txt.utf-8'},
#    'download_count': 1777},
#   {'id': 82,
#    'title': 'Ivanhoe: A Romance',
#    'authors': [{'name': 'Scott, Walter',
#      'birth_year': 1771,
#      'death_year': 1832}],
#    'translators': [],
#    'subjects': ['Anglo-Saxons -- Fiction',
#     'Great Britain -- History -- Richard I, 1189-1199 -- Fiction',
#     'Historical fiction',
#     'Ivanhoe, Wilfred of, Sir (Fictitious character) -- Fiction',
#     'Jews -- England -- Fiction',
#     'Knights and knighthood -- Fiction',
#     'Love stories',
#     'Normans -- Great Britain -- Fiction',
#     'Triangles (Interpersonal relations) -- Fiction'],
#    'bookshelves': ['Best Books Ever Listings', 'Historical Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/82.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/82.epub3.images',
#     'text/html; charset=utf-8': 'https://www.gutenberg.org/files/82/82-h/82-h.htm',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/82/pg82.cover.medium.jpg',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/82/82-0.txt',
#     'text/html': 'https://www.gutenberg.org/ebooks/82.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/82.rdf'},
#    'download_count': 1640},
#   {'id': 25141,
#    'title': 'The Pursuit of God',
#    'authors': [{'name': 'Tozer, A. W. (Aiden Wilson)',
#      'birth_year': 1897,
#      'death_year': 1963}],
#    'translators': [],
#    'subjects': ['God (Christianity) -- Worship and love', 'Spirituality'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/25141.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/25141.epub3.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/25141/pg25141.cover.medium.jpg',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/25141/25141-h/25141-h.htm',
#     'text/plain; charset=iso-8859-1': 'https://www.gutenberg.org/files/25141/25141-8.txt',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/25141/25141.txt',
#     'text/html': 'https://www.gutenberg.org/ebooks/25141.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/25141.rdf',
#     'text/plain': 'https://www.gutenberg.org/ebooks/25141.txt.utf-8'},
#    'download_count': 1589},
#   {'id': 69549,
#    'title': 'The painted room',
#    'authors': [{'name': 'Wilson, Margaret',
#      'birth_year': 1882,
#      'death_year': 1973}],
#    'translators': [],
#    'subjects': ['Families -- Fiction',
#     'First loves -- Fiction',
#     'Mate selection -- Fiction',
#     'Middle West -- Fiction',
#     'United States -- Social life and customs -- 20th century -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'image/jpeg': 'https://www.gutenberg.org/cache/epub/69549/pg69549.cover.medium.jpg',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/69549.rdf',
#     'text/plain': 'https://www.gutenberg.org/ebooks/69549.txt.utf-8',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/69549.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/69549.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/69549.html.images',
#     'application/octet-stream': 'https://www.gutenberg.org/files/69549/69549-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/69549/69549-0.txt'},
#    'download_count': 1394},
#   {'id': 583,
#    'title': 'The Woman in White',
#    'authors': [{'name': 'Collins, Wilkie',
#      'birth_year': 1824,
#      'death_year': 1889}],
#    'translators': [],
#    'subjects': ['Art teachers -- Fiction',
#     'Country homes -- Fiction',
#     'Deception -- Fiction',
#     'England -- Fiction',
#     'Gothic fiction',
#     'Inheritance and succession -- Fiction',
#     'Love stories',
#     'Nobility -- Fiction',
#     'Psychiatric hospital patients -- Fiction',
#     'Psychological fiction'],
#    'bookshelves': ['Mystery Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/583.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/583.epub3.images',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/583/583-h/583-h.htm',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/583/583.txt',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/583/pg583.cover.medium.jpg',
#     'text/html': 'https://www.gutenberg.org/ebooks/583.html.images',
#     'text/plain': 'https://www.gutenberg.org/ebooks/583.txt.utf-8',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/583.rdf'},
#    'download_count': 1367},
#   {'id': 805,
#    'title': 'This Side of Paradise',
#    'authors': [{'name': 'Fitzgerald, F. Scott (Francis Scott)',
#      'birth_year': 1896,
#      'death_year': 1940}],
#    'translators': [],
#    'subjects': ['Advertising -- Fiction',
#     'Bildungsromans',
#     'Children of the rich -- Fiction',
#     'College students -- Fiction',
#     'Love stories',
#     'World War, 1914-1918 -- Veterans -- Fiction',
#     'Young men -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/805.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/805.epub3.images',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/805/805.txt',
#     'text/plain; charset=iso-8859-1': 'https://www.gutenberg.org/files/805/805-8.txt',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/805/805-0.txt',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/805/pg805.cover.medium.jpg',
#     'text/html': 'https://www.gutenberg.org/ebooks/805.html.images',
#     'text/html; charset=utf-8': 'https://www.gutenberg.org/files/805/805-h/805-h.htm',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/805.rdf'},
#    'download_count': 1293},
#   {'id': 963,
#    'title': 'Little Dorrit',
#    'authors': [{'name': 'Dickens, Charles',
#      'birth_year': 1812,
#      'death_year': 1870}],
#    'translators': [],
#    'subjects': ['Children of prisoners -- Fiction',
#     'Debt, Imprisonment for -- Fiction',
#     'Domestic fiction',
#     'Fathers and daughters -- Fiction',
#     'Inheritance and succession -- Fiction',
#     'London (England) -- Fiction',
#     'Love stories',
#     'Marshalsea Prison (Southwark, London, England) -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/963.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/963.epub3.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/963/pg963.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/963/963.txt',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/963/963-0.txt',
#     'text/html; charset=utf-8': 'https://www.gutenberg.org/files/963/963-h/963-h.htm',
#     'text/html': 'https://www.gutenberg.org/ebooks/963.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/963.rdf'},
#    'download_count': 1226},
#   {'id': 883,
#    'title': 'Our Mutual Friend',
#    'authors': [{'name': 'Dickens, Charles',
#      'birth_year': 1812,
#      'death_year': 1870}],
#    'translators': [],
#    'subjects': ['Deception -- Fiction',
#     'Inheritance and succession -- Fiction',
#     'London (England) -- Fiction',
#     'Love stories',
#     'Poor families -- Fiction',
#     'Satire',
#     'Social classes -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/883.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/883.epub3.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/883/pg883.cover.medium.jpg',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/883/883-0.txt',
#     'text/html; charset=utf-8': 'https://www.gutenberg.org/files/883/883-h/883-h.htm',
#     'text/html': 'https://www.gutenberg.org/ebooks/883.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/883.rdf'},
#    'download_count': 1169},
#   {'id': 9182,
#    'title': 'Villette',
#    'authors': [{'name': 'Brontë, Charlotte',
#      'birth_year': 1816,
#      'death_year': 1855}],
#    'translators': [],
#    'subjects': ['Autobiographical fiction',
#     'British -- Belgium -- Fiction',
#     'Brussels (Belgium) -- Fiction',
#     'Love stories',
#     'Women teachers -- Fiction'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/9182.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/9182.epub3.images',
#     'text/plain; charset=iso-8859-1': 'https://www.gutenberg.org/files/9182/9182-8.txt',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/9182/pg9182.cover.medium.jpg',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/9182/9182-0.txt',
#     'text/html; charset=utf-8': 'https://www.gutenberg.org/files/9182/9182-h/9182-h.htm',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/9182/9182.txt',
#     'text/html': 'https://www.gutenberg.org/ebooks/9182.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/9182.rdf'},
#    'download_count': 1126},
#   {'id': 1600,
#    'title': 'Symposium',
#    'authors': [{'name': 'Plato', 'birth_year': -428, 'death_year': -348}],
#    'translators': [{'name': 'Jowett, Benjamin',
#      'birth_year': 1817,
#      'death_year': 1893}],
#    'subjects': ['Classical literature',
#     'Love -- Early works to 1800',
#     'Philosophy, Ancient',
#     'Socrates, 470 BC-399 BC'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/1600.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/1600.epub3.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/1600/pg1600.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/1600/1600.txt',
#     'text/html; charset=us-ascii': 'https://www.gutenberg.org/files/1600/1600-h/1600-h.htm',
#     'text/html': 'https://www.gutenberg.org/ebooks/1600.html.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/1600.rdf',
#     'text/plain': 'https://www.gutenberg.org/ebooks/1600.txt.utf-8'},
#    'download_count': 1113},
#   {'id': 3618,
#    'title': 'Arms and the Man',
#    'authors': [{'name': 'Shaw, Bernard',
#      'birth_year': 1856,
#      'death_year': 1950}],
#    'translators': [],
#    'subjects': ['Bulgaria -- Drama',
#     'Italians -- Bulgaria -- Drama',
#     'Love -- Drama',
#     'Man-woman relationships -- Drama',
#     'Serbo-Bulgarian War, 1885 -- Drama',
#     'Soldiers -- Bulgaria -- Drama',
#     'War -- Drama'],
#    'bookshelves': [],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/3618.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/3618.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/3618.html.images',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/3618/pg3618.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/3618/3618-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/3618/3618-0.txt',
#     'text/plain': 'https://www.gutenberg.org/ebooks/3618.txt.utf-8',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/3618.rdf'},
#    'download_count': 1002},
#   {'id': 5921,
#    'title': 'The History of Don Quixote, Volume 1, Complete',
#    'authors': [{'name': 'Cervantes Saavedra, Miguel de',
#      'birth_year': 1547,
#      'death_year': 1616}],
#    'translators': [{'name': 'Ormsby, John',
#      'birth_year': 1829,
#      'death_year': 1895}],
#    'subjects': ['Knights and knighthood -- Spain -- Fiction',
#     'Picaresque literature',
#     'Romances',
#     'Spain -- Social life and customs -- 16th century -- Fiction'],
#    'bookshelves': ['6 Best Loved Spanish Literary Classics',
#     "Banned Books from Anne Haight's list",
#     'Best Books Ever Listings'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/5921.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/5921.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/5921.html.images',
#     'application/octet-stream': 'https://www.gutenberg.org/files/5921/5921-0.zip',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/5921/pg5921.cover.medium.jpg',
#     'text/plain': 'https://www.gutenberg.org/ebooks/5921.txt.utf-8',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/5921/5921-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/5921.rdf'},
#    'download_count': 987},
#   {'id': 6688,
#    'title': 'The Mill on the Floss',
#    'authors': [{'name': 'Eliot, George',
#      'birth_year': 1819,
#      'death_year': 1880}],
#    'translators': [],
#    'subjects': ['Conflict of generations -- Fiction',
#     'Domestic fiction',
#     'England -- Fiction',
#     'Loss (Psychology) -- Fiction',
#     'Love stories',
#     'Psychological fiction',
#     'Siblings -- Fiction',
#     'Vendetta -- Fiction',
#     'Water mills -- Fiction',
#     'Young women -- Fiction'],
#    'bookshelves': ['Harvard Classics'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/6688.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/6688.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/6688.html.images',
#     'application/octet-stream': 'https://www.gutenberg.org/files/6688/6688-0.zip',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/6688/pg6688.cover.medium.jpg',
#     'text/plain': 'https://www.gutenberg.org/ebooks/6688.txt.utf-8',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/6688/6688-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/6688.rdf'},
#    'download_count': 965},
#   {'id': 153,
#    'title': 'Jude the Obscure',
#    'authors': [{'name': 'Hardy, Thomas',
#      'birth_year': 1840,
#      'death_year': 1928}],
#    'translators': [],
#    'subjects': ['Adultery -- Fiction',
#     'Children -- Death -- Fiction',
#     'Didactic fiction',
#     'Illegitimate children -- Fiction',
#     'Love stories',
#     'Stonemasons -- Fiction',
#     'Unmarried couples -- Fiction',
#     'Wessex (England) -- Fiction'],
#    'bookshelves': ["Banned Books from Anne Haight's list"],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/153.kf8.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/153.epub3.images',
#     'text/html': 'https://www.gutenberg.org/ebooks/153.html.images',
#     'text/plain': 'https://www.gutenberg.org/ebooks/153.txt.utf-8',
#     'application/octet-stream': 'https://www.gutenberg.org/files/153/153-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/153/153-0.txt',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/153/pg153.cover.medium.jpg',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/153.rdf'},
#    'download_count': 913}]}

# %% [markdown]
# ## The Reddit API
#
# 1. Register for a Reddit account
# 2. Go to https://www.reddit.com/prefs/apps and create a script app.
# 3. Fill out the relevant fields, putting http://localhost:8080 for the URL fields
# 4. Record the client_id (top left) and secret. The user_agent field can be arbitrary.
# 5. The auth credentials are as follows:
#    `reddit = praw.Reddit(user_agent='YOURUSERAGENT',
#    client_id='YOURCLIENTID', client_secret="SECRET",
#    username='USERNAME', password='PASSWORD')`

# %%
reddit = praw.Reddit(user_agent='VAD',
                     client_id='eCo_TWE_BA_zFA', client_secret="1gsqXgMrZBoQBVYf40hgtvMS_Ro",
                     username='textureai', password='7233190s')
# Out:
# Version 7.6.0 of praw is outdated. Version 7.6.1 was released Friday November 11, 2022.

# %%
def submission(submission_id): ## submission_id can be URL or submission ID
    try:
        submission = reddit.submission(url = submission_id)
    except:
        submission = reddit.submission(submission_id)
    title = submission.title
    submission.comments.replace_more() ## loads new page if cooments are multipage
    text = [i.body for i in submission.comments]
    score = [i.score for i in submission.comments]
    user = [i.author for i in submission.comments]
    date = [datetime.datetime.fromtimestamp(i.created) for i in submission.comments]
    df = pd.DataFrame()
    df['text'] = text
    df['datetime'] = date
    df['score'] = score
    df['subreddit'] = submission.subreddit
    df['redditor'] = user
    df['type'] = 'comment'
    df['title'] = title
    df = df.sort_values('score', ascending = False).reset_index(drop = True)
    return df

# %%
df = submission('https://www.reddit.com/r/AskReddit/comments/10orx1j/what_movies_soundtrack_is_an_absolute_banger/')

# %% [markdown]
# # Exercises
#
# 1. Write functions for interacting with the Reddit API that retrieve comments by (a) subreddit aand (b) by specific Reddit user and saves the result as a dataframe.
# 2. Identify a topic of interest to you and retrieve the top 1k comments on that subreddit.
# 3. Create a new column in your dataframe and that consists of the tokenized and lemmatized comments
